# %% [markdown]
# # Step 2: Calculate binned methylation around MEs

# %% [markdown]
# Given the lists of MEVs generated in step 1, calculate methylation levels in bins around each MEV.

# %% [markdown]
# ## Load variants

# %%
import pandas as pd
import pyarrow
import numpy as np
from glob import glob
import os,re
from multiprocessing import Pool
from tqdm import tqdm
from itertools import repeat

import sys
# add path to src module - note this is not a Pythonic solution
sys.path.insert(1, '../') 

from src import calculate_mC

# %%
me_type = 'L1'
var_type = 'absence'
binsize = 100
nbins = 20
ctxt = 'CGN CHN'

allc_path = '/home/AD/rkgadde/L1IP/celltype_allc'
genome = '/home/AD/rkgadde/L1IP/hg38_data/hg38.sorted.genome'

pdir = '/home/AD/rkgadde/L1IP/mC_data/CZI/type'
me_file = f'{pdir}/vars/all_{me_type}_{var_type[:3]}.tsv'

# %%
var = var_type[:3]
variant = f'{me_type}_{var}'

bindir = f'{pdir}/bins'
outdir = f'{pdir}/mC'
tmpdir = f'{pdir}/tmp'

# %%
me_df = pd.read_csv(me_file, sep='\t', 
                    names=['chrom','start','end','id','svlen','strand','mei','het','alt'])
me_df.head()
# Out:
#   chrom     start       end            id  svlen strand   mei  \
# 0  chr1  56365451  56369289  CZI_abs_1543   3837      +  L1HS
# 1  chr1  65443954  65444209  CZI_abs_1545    254      -  L1HS
# 2  chr1  80939086  80945263  CZI_abs_1546   6176      -  L1HS
# 3  chr1  82660292  82661886  CZI_abs_1547   1593      +  L1HS
# 4  chr1  86275302  86276014  CZI_abs_1548    711      +  L1HS
#
#                        het                          alt
# 0      AM1,AM2,AM3,YF2,YM3          AF1,AF2,YF1,YM1,YM2
# 1              AF1,YM1,YM3  AF2,AF3,AM1,AM2,AM3,YF1,YF2
# 2  AF2,AF3,AM1,YF1,YM1,YM3          AF1,AM2,AM3,YF2,YM2
# 3          AF1,AF2,AM2,YF1  AF3,AM1,AM3,YF2,YM1,YM2,YM3
# 4  AF1,AM1,YF1,YM1,YM2,YM3          AF2,AF3,AM2,AM3,YF2

# %%
bedfile = me_df[['chrom','start','end','id','strand']]

# %% [markdown]
# ## Make bins

# %%
# Create bins
bed_bins_df = calculate_mC.make_flanking_bins(bedfile, nbins, binsize)

# %%
# Index and merge bins
bin_prefix = me_file.split('/')[-1]
bin_prefix = re.match(r'(.*)\.tsv', bin_prefix).group(1) + '.bins'
calculate_mC.process_bins(bed_bins_df, bin_prefix, bindir)

# %% [markdown]
# ## Calculate methylation for each bin

# %%
# Make directories
# !mkdir -p {tmpdir}/allc_regions-{binsize}
# !mkdir -p {tmpdir}/binc-{binsize}

# %%
allc_tables = glob(f'{allc_path}/*.allc.tsv.gz')
allc_prefix = f'{tmpdir}/allc_regions-{binsize}/allc_{me_type}_{var}'
merge_bed = f'{bindir}/{bin_prefix}.merged.bed'

# %%
# Use tabix to extract the portions of allc tables from the deletion regions.
# This will speed up subsequent processing to calculate the binned data
with Pool(16) as p:
    x = list(tqdm(p.starmap(calculate_mC.tabixallc, 
                            zip(allc_tables, 
                                repeat(allc_prefix), 
                                repeat(merge_bed)))))
# Out:
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AF3.tsv.gz
# command	tabix-allc
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AM2.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AM2.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-YF1.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-YM2.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AM3.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AM1.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AM3.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-YF2.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-YM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-YF1.tsv.gz
# reindex	False
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-YM1.tsv.gz
# reindex	False
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-YF2.tsv.gz
# reindex	False
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AF3.tsv.gz
# reindex	False
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-YM3.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-YM2.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-YM2.tsv.gz
# reindex	False
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-YM1.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-YF2.tsv.gz
# command	tabix-allc
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AF3.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-YM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-YM1.tsv.gz
# reindex	False
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-AM2.tsv.gz
# reindex	False
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-YF1.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-YF1.tsv.gz
# reindex	False
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-YF2.tsv.gz
# reindex	False
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_PVALB-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_LRRK1-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_PAX6-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AF3.tsv.gz
# reindex	False
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-YM3.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AF3.tsv.gz
# reindex	False
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5_LHX6-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6CT_TLE4_FAM95C-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-AF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-AM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-YF1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-AF2.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-AM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-YM1.tsv.gz
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L2-4IT_CUX2-AF2.tsv.gz
# reindex	False
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST_CLMP-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.MGE_SST-YF2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-YF1.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_LAMP5-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_VIP-YM1.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L56NP_TLE4_TSHZ2-YM3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_TSHZ2-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L4-5IT_RORB_ARHGAP15-AM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L3-5IT_RORB_PLCH1-AF2.tsv.gz
# reindex	False
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_CUX1-YM1.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.CGE_ADARB2_ADAM33-AF3.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6b_TLE4_NXPH4-YM2.tsv.gz
# reindex	False
# command	tabix-allc
# allc_path	/home/AD/rkgadde/L1IP/mC_data/CZI/type/tmp/allc_regions-100/allc_L1_abs.L6IT_THEMIS_LINC00343-AM1.tsv.gz
# reindex	False
# Executing tabix-allc...
# tabix-allc finished.
# Executing tabix-allc...
# Executing tabix-allc...
# tabix-allc finished.
# tabix-allc finished.
# Executing tabix-allc...
# tabix-allc finished.
# 100%|██████████| 209/209 [00:00<00:00, 1277856.47it/s]

# %%
allcdir = f'{tmpdir}/allc_regions-{binsize}'
allc_files = glob(f'{allcdir}/allc_{variant}.*.tsv.gz')
bed_bins_file = f'{bindir}/{bin_prefix}.bed.gz'
binc_prefix = f'{tmpdir}/binc-{binsize}/binc'

# %%
# Use allcools to calculate the binned mC counts 
with Pool(16) as p:
    x = list(tqdm(p.starmap(calculate_mC.allc2bins, 
                            zip(allc_files, 
                                repeat(binc_prefix), 
                                repeat(variant), 
                                repeat(genome), 
                                repeat(bed_bins_file),
                                repeat(ctxt)))))
# Out:
# 100%|██████████| 209/209 [00:00<00:00, 679542.28it/s]

# %%
# Load the binned mC data
cn = ctxt.split(' ')[0]
mc_files = glob(f'{binc_prefix}*{variant}_{cn}-Both.sparse.bed.gz')
samples_celltypes = []

for mc_file in mc_files:
    sample = re.match(fr'.*binc\.(.*)\.{variant}_{cn}-Both\.sparse\.bed\.gz', mc_file).group(1)
    samples_celltypes.append(sample)
len(samples_celltypes)
# Out:
# 209

# %%
# Combine binned mC data
with Pool(16) as p:
    mc_dfs = list(tqdm(p.starmap(calculate_mC.get_binc, 
                              zip(samples_celltypes, 
                                  repeat(binc_prefix), 
                                  repeat(variant),
                                  repeat(ctxt)))))
# Out:
# 100%|██████████| 209/209 [00:00<00:00, 722678.92it/s]

# %%
mc_df = pd.concat(mc_dfs)

# %% [markdown]
# ## Mark genotype for each sample at each locus

# %%
ids = me_df['id'].unique()

with Pool(16) as p:
    gt_dfs = list(tqdm(p.starmap(calculate_mC.groupby_gt, 
                              zip(ids, 
                                  repeat(me_df), 
                                  repeat(mc_df), 
                                  repeat(me_type)))))
# Out:
# 100%|██████████| 122/122 [00:00<00:00, 485949.75it/s]

# %%
gt_df = pd.concat(gt_dfs)

# %% [markdown]
# ## Export data

# %%
# %%time

# TODO: Change to rewrite file if tmp files are newer
filepath = f'{outdir}/binc-{binsize}.{variant}.all_samples.parquet.gz'

if not os.path.isfile(filepath):
    gt_df.to_parquet(filepath, compression='gzip', index=False)
# Out:
# CPU times: user 987 ms, sys: 71.9 ms, total: 1.06 s
# Wall time: 1.05 s
